# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Datasets/results.xlsx')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a combined gender_ethnicity column
df['gender_ethnicity'] = df['gender'] + ' ' + df['ethnicity']

# Make HSCs positive
df['HSCs'] = df['HSCs'].abs()

# Build a gender-based color palette (solid colors for all)
palette = {
    'Male non-Māori': 'blue',
    'Female non-Māori': 'red',
    'Male Māori': 'blue',
    'Female Māori': 'red'
}

# Plot QALYs
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='age', y='QALYs', hue='gender_ethnicity', data=df, palette=palette)
add_hatches(ax)
plt.title('QALYs by Age, Disaggregated by Gender and Ethnicity')
plt.xlabel('Age Group')
plt.ylabel('QALYs per 1000 people')
plt.xticks(rotation=45)
plt.legend(title='Gender & Ethnicity')
plt.tight_layout()
plt.show()

# Plot HSCs
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='age', y='HSCs', hue='gender_ethnicity', data=df, palette=palette)
add_hatches(ax)
plt.title('Health System Savings by Age, Disaggregated by Gender and Ethnicity')
plt.xlabel('Age Group')
plt.ylabel('Health System Savings')
plt.xticks(rotation=45)
plt.legend(title='Gender & Ethnicity')
plt.tight_layout()
plt.show()
# Out:
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
# Male non-Māori
# Female non-Māori
# Male Māori
# Female Māori
