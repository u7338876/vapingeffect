# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Datasets/results.xlsx')

# %%
# Create a combined gender_ethnicity column for grouping
df['gender_ethnicity'] = df['gender'] + ' ' + df['ethnicity']

# Make HSCs positive
df['HSCs'] = df['HSCs'].abs()

# Plotting the bar graphs
plt.figure(figsize=(12, 6))
sns.barplot(x='age', y='QALYs', hue='gender_ethnicity', data=df)
plt.title('QALYs by Age, Disaggregated by Gender and Ethnicity')
plt.xlabel('Age Group')
plt.ylabel('QALYs')
plt.xticks(rotation=45)
plt.legend(title='Gender & Ethnicity')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x='age', y='HSCs', hue='gender_ethnicity', data=df)
plt.title('Health System Savings by Age, Disaggregated by Gender and Ethnicity')
plt.xlabel('Age Group')
plt.ylabel('Positive HSCs')
plt.xticks(rotation=45)
plt.legend(title='Gender & Ethnicity')
plt.tight_layout()
plt.show()
